# %%
custom_lib <- "/kaggle/input/library-data/my_r_libs"  
default_lib <- .libPaths()[1] 

packages <- list.dirs(custom_lib, full.names = TRUE, recursive = FALSE)

# move packages from custom to default library path
for (pkg in packages) {
  pkg_name <- basename(pkg)  
  target_path <- file.path(default_lib, pkg_name)
  
  # check if the package already exists in the default path
  if (!dir.exists(target_path)) {
    file.copy(pkg, default_lib, recursive = TRUE)
  } else {
    message(paste("package already exists in default library:", pkg_name))
  }
}
print('-----------------All packages are moved----------------------')
# Out:
# package already exists in default library: bslib
#
# package already exists in default library: digest
#
# package already exists in default library: e1071
#
# package already exists in default library: evaluate
#
# package already exists in default library: knitr
#
# package already exists in default library: openssl
#
# package already exists in default library: Rcpp
#
# package already exists in default library: RcppArmadillo
#
# package already exists in default library: RcppEigen
#
# package already exists in default library: reticulate
#
# package already exists in default library: rmarkdown
#
# package already exists in default library: RSpectra
#
# package already exists in default library: tinytex
#
# package already exists in default library: uuid
#
# package already exists in default library: withr
#
# package already exists in default library: xfun
#
# package already exists in default library: yaml
# [1] "-----------------All packages are moved----------------------"

# %%
devtools::install_github("MRCIEU/TwoSampleMR")
# Out:
# ...
# MRMix       (NA        -> 56afdb2bc...) [GitHub]
# MRPRESSO    (NA        -> 3e3c92d7e...) [GitHub]
# RadialMR    (NA        -> 4ec0e0931...) [GitHub]
# xfun        (0.45      -> 0.52        ) [CRAN]
# yaml        (2.3.8     -> 2.3.10      ) [CRAN]
# evaluate    (0.24.0    -> 1.0.3       ) [CRAN]
# rlang       (1.1.4     -> 1.1.5       ) [CRAN]
# digest      (0.6.36    -> 0.6.37      ) [CRAN]
# R6          (2.5.1     -> 2.6.1       ) [CRAN]
# fs          (1.6.4     -> 1.6.5       ) [CRAN]
# glue        (1.7.0     -> 1.8.0       ) [CRAN]
# cli         (3.6.3     -> 3.6.4       ) [CRAN]
# mime        (0.12      -> 0.13        ) [CRAN]
# jsonlite    (1.8.8     -> 2.0.0       ) [CRAN]
# stringi     (1.8.4     -> 1.8.7       ) [CRAN]
# Rcpp        (1.0.12    -> 1.0.14      ) [CRAN]
# sys         (3.4.2     -> 3.4.3       ) [CRAN]
# tinytex     (0.51      -> 0.56        ) [CRAN]
# fontawesome (0.5.2     -> 0.5.3       ) [CRAN]
# bslib       (0.7.0     -> 0.9.0       ) [CRAN]
# ...

# %%
library(TwoSampleMR)

# %% [markdown]
# ______________

# %% [markdown]
# ------------------

# %%
# bmi korean pop GWAS summary stat
download.file('https://koges.leelabsg.org/download/KoGES_BMI', 'koges_bmi.txt.gz')

# %%
options(timeout = 700)
# t2d japanese pop GWAS summary stat
download.file('https://pheweb.jp/download/T2D', 'bbj_t2d.zip')

# %%
unzip("bbj_t2d.zip")

# %%
# cad japanese pop GWAS summary stat
download.file('https://humandbs.dbcls.jp/files/hum0014/hum0014_v20_gwas_v1.zip', 'hum0014_v20_gwas_v1.zip')

# %%
unzip('hum0014_v20_gwas_v1.zip')

# %%
Sys.setenv(OPENGWAS_JWT = "eyJhbGciOiJSUzI1NiIsImtpZCI6ImFwaS1qd3QiLCJ0eXAiOiJKV1QifQ.eyJpc3MiOiJhcGkub3Blbmd3YXMuaW8iLCJhdWQiOiJhcGkub3Blbmd3YXMuaW8iLCJzdWIiOiJpYnJhaGltbWFmcmVnMUB5YWhvby5jb20iLCJpYXQiOjE3NDM4MTc3MzcsImV4cCI6MTc0NTAyNzMzN30.wDD5tptish5UuLRZXiT1hzv_gb5dMRAXrC03N7A0DRzh1QJg8cjCz_dNodKafxfc82SerkBh19kxHNxaZlAgtM7uT_VM6E6rvLibJJOZsrl9Y6HZ6u4SkfBKX6NqFN3VxWayWlTTjB8mDShN9k5aupuBdFglL3HOZiHUbLCRdxWyewqEIITLv2D1zBxgMo1GyLUlf2c13NRidJWuuquteZc92RQ8ihXi8pBgglB-XiMnZHo3HNjj3tiekBAiX1eTNRYrALDGMqjFnTl1-F548zaAft2gw-ksp2lKJr9jOqEQZow6ggmaYTCI_0pxCRF2G5zxJ3q5pnOJ7zuYW5HnzA")

# %% [markdown]
# - T2D (exposure 1)
#
# - BMI (exposure 2)

# %%
install.packages('ieugwasr')
# Out:
# Installing package into ‘/usr/local/lib/R/site-library’
# (as ‘lib’ is unspecified)

# %%
library(data.table)

# %%
Sys.setenv(OPENGWAS_JWT = "eyJhbGciOiJSUzI1NiIsImtpZCI6ImFwaS1qd3QiLCJ0eXAiOiJKV1QifQ.eyJpc3MiOiJhcGkub3Blbmd3YXMuaW8iLCJhdWQiOiJhcGkub3Blbmd3YXMuaW8iLCJzdWIiOiJpYnJhaGltbWFmcmVnMUB5YWhvby5jb20iLCJpYXQiOjE3NDM4MTc3MzcsImV4cCI6MTc0NTAyNzMzN30.wDD5tptish5UuLRZXiT1hzv_gb5dMRAXrC03N7A0DRzh1QJg8cjCz_dNodKafxfc82SerkBh19kxHNxaZlAgtM7uT_VM6E6rvLibJJOZsrl9Y6HZ6u4SkfBKX6NqFN3VxWayWlTTjB8mDShN9k5aupuBdFglL3HOZiHUbLCRdxWyewqEIITLv2D1zBxgMo1GyLUlf2c13NRidJWuuquteZc92RQ8ihXi8pBgglB-XiMnZHo3HNjj3tiekBAiX1eTNRYrALDGMqjFnTl1-F548zaAft2gw-ksp2lKJr9jOqEQZow6ggmaYTCI_0pxCRF2G5zxJ3q5pnOJ7zuYW5HnzA")

# %%
t2d <- fread("/kaggle/working/hum0197.v3.BBJ.T2D.v1/GWASsummary_T2D_Japanese_SakaueKanai2020.auto.txt.gz")
t2d<- data.frame(t2d)

# bmi <- fread("koges_bmi.txt.gz")
# bmi<- data.frame(bmi)

# %%
bmi<- bmi[!bmi$effect_allele.exposure == 'GGTGT',]

# %%
# select only significant variants
bmi <- subset(bmi,bmi$pval<1e-6)

bmi <- format_data( bmi,
    type = "exposure",
    snp_col = "rsids",
    beta_col = "beta",
    se_col = "sebeta",
    effect_allele_col = "alt",
    other_allele_col = "ref",
    eaf_col = "af",
    pval_col = "pval",
)
# Out:
# No phenotype name specified, defaulting to 'exposure'.
#
# Warning message in .fun(piece, ...):
# “Duplicated SNPs present in exposure data for phenotype 'exposure. Just keeping the first instance:
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# rs4665740
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# rs7201608
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# ”

# %%
head(bmi)
head(t2d)
# Out:
#   pos.exposure other_allele.exposure effect_allele.exposure SNP
# 1 49213402     C                     T                      rs12024474
# 2 49214762     C                     T                      rs1872279
# 3 49426752     G                     GGTGT
# 4 49433003     A                     C                      rs1343431
# 5 49437617     T                     A                      rs1343425
# 6 49438005     G                     A                      rs3127553
#   pval.exposure beta.exposure se.exposure eaf.exposure exposure
# 1 6.1e-07       -0.028        0.0056      0.33         exposure
# 2 5.6e-07       -0.029        0.0057      0.33         exposure
# 3 3.4e-07       -0.032        0.0062      0.23         exposure
# 4 4.6e-07       -0.028        0.0055      0.33         exposure
# 5 6.3e-07       -0.027        0.0055      0.33         exposure
# 6 6.4e-07       -0.027        0.0055      0.33         exposure
#   mr_keep.exposure pval_origin.exposure id.exposure
# ...

# %%
# select only significant variants
t2d <- subset(t2d,t2d$p.value<1e-6)

t2d <- format_data( t2d,
    type = "exposure",
    snp_col = "SNPID",
    beta_col = "BETA",
    se_col = "SE",
    effect_allele_col = "Allele2",
    other_allele_col = "Allele1",
    eaf_col = "AF_Allele2",
    pval_col = "p.value	",
                   pos_col = 'POS'
)
# Out:
# No phenotype name specified, defaulting to 'exposure'.
#
# Warning message in format_data(t2d, type = "exposure", snp_col = "SNPID", beta_col = "BETA", :
# “effect_allele column has some values that are not A/C/T/G or an indel comprising only these characters or D/I. These SNPs will be excluded.”
# Inferring p-values
#
# Warning message in format_data(t2d, type = "exposure", snp_col = "SNPID", beta_col = "BETA", :
# “The following SNP(s) are missing required information for the MR tests and will be excluded: 2:652672:a:<ins:me:alu> 3:23298159:c:<ins:me:alu> 4:85219752:a:<ins:me:alu> 6:20887919:t:<ins:me:alu> 6:31023272:g:<cn0> 6:31250241:t:<ins:me:alu> 6:31304015:t:<ins:me:alu> 7:89810410:c:<cn0> 7:127214967:a:<cn0> 15:77330749:c:<cn0>”

# %%
dim(t2d)
sort(colnames(t2d))
dim(bmi)
sort(colnames(bmi))
# Out:
# [1] 15376    12
#  [1] "beta.exposure"          "eaf.exposure"           "effect_allele.exposure"
#  [4] "exposure"               "id.exposure"            "mr_keep.exposure"
#  [7] "other_allele.exposure"  "pos.exposure"           "pval_origin.exposure"
# [10] "pval.exposure"          "se.exposure"            "SNP"
# [1] 4336   12
#  [1] "beta.exposure"          "eaf.exposure"           "effect_allele.exposure"
#  [4] "exposure"               "id.exposure"            "mr_keep.exposure"
#  [7] "other_allele.exposure"  "pos.exposure"           "pval_origin.exposure"
# [10] "pval.exposure"          "se.exposure"            "SNP"

# %%
head(bmi)
head(t2d)
# Out:
#   pos.exposure other_allele.exposure effect_allele.exposure SNP
# 1 49213402     C                     T                      rs12024474
# 2 49214762     C                     T                      rs1872279
# 3 49426752     G                     GGTGT
# 4 49433003     A                     C                      rs1343431
# 5 49437617     T                     A                      rs1343425
# 6 49438005     G                     A                      rs3127553
#   pval.exposure beta.exposure se.exposure eaf.exposure exposure
# 1 6.1e-07       -0.028        0.0056      0.33         exposure
# 2 5.6e-07       -0.029        0.0057      0.33         exposure
# 3 3.4e-07       -0.032        0.0062      0.23         exposure
# 4 4.6e-07       -0.028        0.0055      0.33         exposure
# 5 6.3e-07       -0.027        0.0055      0.33         exposure
# 6 6.4e-07       -0.027        0.0055      0.33         exposure
#   mr_keep.exposure pval_origin.exposure id.exposure
# ...

# %%
unique(t2d$id.exposure)
# Out:
# [1] "1BoN59"

# %% [markdown]
# We’ll extract significant SNPs for:

# %%
c_bmi_exp <- clump_data(bmi, pop ='EAS')
# Out:
# Please look at vignettes for options on running this locally if you need to run many instances of this command.
#
# Clumping Z4DqzZ, 4336 variants, using EAS population reference
#
# Removing 4273 of 4336 variants due to LD with other variants or absence from LD reference panel

# %%
c_t2d_exp <- clump_data(t2d, pop ='EAS')
# Out:
# Please look at vignettes for options on running this locally if you need to run many instances of this command.
#
# Clumping 1BoN59, 15376 variants, using EAS population reference
#
# Removing 15244 of 15376 variants due to LD with other variants or absence from LD reference panel

# %%
c_bmi_exp <- bmi
c_t2d_exp <- t2d

# %%
# Add exposure names
c_t2d_exp$exposure <- "CUisng_T2D"
c_bmi_exp$exposure <- "f1j5gq_BMI"

# %% [markdown]
# # testing BMI and t2d on CAD

# %%
exposures_mv <- rbind(c_t2d_exp, c_bmi_exp, fill = TRUE)

# %%
# reading cad data 
cad_dat <- fread("BBJCAD_2020.sumstats")

# %%
t2d <- fread("/kaggle/working/hum0197.v3.BBJ.T2D.v1/GWASsummary_T2D_Japanese_SakaueKanai2020.auto.txt.gz")
t2d<- data.frame(t2d)

# bmi <- fread("koges_bmi.txt.gz")

# %%
colnames_only <- fread("/kaggle/working/hum0197.v3.BBJ.T2D.v1/GWASsummary_T2D_Japanese_SakaueKanai2020.auto.txt.gz", nrows = 0)
colnames_only
# Out:
#      v CHR POS SNPID Allele1 Allele2 AC_Allele2 AF_Allele2 imputationInfo N
#      BETA SE Tstat p.value p.value.NA Is.SPA.converge varT varTstar AF.Cases
#      AF.Controls

# %%
colnames_only <- fread("koges_bmi.txt.gz", nrows = 0)
colnames_only
# Out:
#      chrom pos ref alt rsids nearest_genes pval beta sebeta af ac tstat

# %%
snp1= fread('hum0197.v3.BBJ.T2D.v1/GWASsummary_T2D_Japanese_SakaueKanai2020.auto.txt.gz', select=c('POS','CHR','SNPID'))
snp2= fread('koges_bmi.txt.gz', select=c('pos','chrom','rsids'))

# %%
setnames(snp2, old = c("pos", 'chrom', "rsids"), 
                   new = c("pos",'chr', "SNP"))
setnames(snp1, old = c("POS", 'CHR', "SNPID"), 
                   new = c("pos",'chr', "SNP"))
snp1$pos <- as.integer(snp1$pos)
snp1$chr <- as.integer(snp1$chr)
# Out:
# Warning message in eval(expr, envir, enclos):
# “NAs introduced by coercion”

# %%
snped<- merge(snp1, snp2, by = c("pos",'chr', "SNP"))
dim(snped)
# Out:
# [1] 6023533       3

# %%
setnames(cad_dat, old = c("POS", 'CHR'), 
                   new = c("pos",'chr'))

# %%
head(cad_dat)
# Out:
#   chr pos    REF ALT AAF        BETA         SE        P         N
# 1 1   752566 G   A   0.84284200 -0.002439450 0.0135104 0.8567120 168228
# 2 1   754198 A   G   0.02062810 -0.010420700 0.0558166 0.8518990 168228
# 3 1   754429 T   G   0.09071460  0.046525100 0.0273711 0.0891699 168228
# 4 1   757665 C   A   0.00260283 -0.267805000 0.1833220 0.1440580 168228
# 5 1   759050 G   T   0.08964900  0.049065300 0.0272701 0.0719811 168228
# 6 1   759293 T   A   0.15083900 -0.000013594 0.0140821 0.9992300 168228

# %%
# Merge
cad_merged <- merge(snped, cad_dat, by = c("chr", "pos"))

# %%
head(cad_merged)
# Out:
#   chr pos    SNP        REF ALT AAF      BETA         SE        P        N
# 1 1   752566 rs3094315  G   A   0.842842 -2.43945e-03 0.0135104 0.856712 168228
# 2 1   759293 rs10157329 T   A   0.150839 -1.35940e-05 0.0140821 0.999230 168228
# 3 1   759837 rs3115851  T   A   0.842986 -2.72262e-03 0.0136626 0.842047 168228
# 4 1   760912 rs1048488  C   T   0.841994 -2.96531e-03 0.0136848 0.828453 168228
# 5 1   761147 rs3115850  T   C   0.841946 -2.54470e-03 0.0136869 0.852505 168228
# 6 1   762589 rs3115848  G   C   0.852839  9.15141e-06 0.0144274 0.999494 168228

# %%
cad_outcome_dat <- format_data(data.frame(cad_merged),
                               type = "outcome",
                               snp_col  = 'SNP',
                               beta_col ='BETA',
                               se_col = 'SE',
                               eaf_col = 'AAF',
                               effect_allele_col = 'ALT',
                               other_allele_col = 'REF',
                               pval_col = 'P'
                              )
# Out:
# No phenotype name specified, defaulting to 'outcome'.

# %%
# exposures_dat<- readRDS('exposures_dat.rds')

# %%
# cad_outcome_dat<- readRDS('cad_outcome_dat.rds')

# %%
exposures_data <- exposures_dat
exposures_data$mr_keep <- TRUE

# %% [markdown]
# # BMI on CAD

# %%
harmonized_data <- harmonise_data(exposure_dat=c_bmi_exp,
                                  outcome_dat=cad_outcome_dat)
# Out:
# Harmonising exposure (Z4DqzZ) and outcome (uxBr3b)
#
# Removing the following SNPs for being palindromic with intermediate allele frequencies:
# rs9348441

# %%
res <- mr(harmonized_data)
head(res)
# Out:
# Analysing 'Z4DqzZ' on 'uxBr3b'
#   id.exposure id.outcome outcome exposure method                    nsnp
# 1 Z4DqzZ      uxBr3b     outcome exposure MR Egger                  43
# 2 Z4DqzZ      uxBr3b     outcome exposure Weighted median           43
# 3 Z4DqzZ      uxBr3b     outcome exposure Inverse variance weighted 43
# 4 Z4DqzZ      uxBr3b     outcome exposure Simple mode               43
# 5 Z4DqzZ      uxBr3b     outcome exposure Weighted mode             43
#   b          se         pval
# 1 0.04070201 0.45346106 0.928916133
# 2 0.19960198 0.07469257 0.007533015
# 3 0.07827809 0.15031267 0.602528111
# 4 0.19544510 0.12679982 0.130728908
# 5 0.22595161 0.09181651 0.018051505

# %%
mr_heterogeneity(harmonized_data)
# Out:
#   id.exposure id.outcome outcome exposure method                    Q
# 1 Z4DqzZ      uxBr3b     outcome exposure MR Egger                  477.8632
# 2 Z4DqzZ      uxBr3b     outcome exposure Inverse variance weighted 477.9534
#   Q_df Q_pval
# 1 41   8.195371e-76
# 2 42   2.707141e-75

# %%
mr_pleiotropy_test(harmonized_data)
# Out:
#   id.exposure id.outcome outcome exposure egger_intercept se         pval
# 1 Z4DqzZ      uxBr3b     outcome exposure 0.001531873     0.01741513 0.9303349

# %%
res_single <- mr_singlesnp(harmonized_data)
head(res_single)
# Out:
#   exposure outcome id.exposure id.outcome samplesize SNP        b
# 1 exposure outcome Z4DqzZ      uxBr3b     NA         rs10198356  0.1268905
# 2 exposure outcome Z4DqzZ      uxBr3b     NA         rs1020222  -0.5626750
# 3 exposure outcome Z4DqzZ      uxBr3b     NA         rs10276442  1.2713879
# 4 exposure outcome Z4DqzZ      uxBr3b     NA         rs10938397  0.6176333
# 5 exposure outcome Z4DqzZ      uxBr3b     NA         rs11041978  0.2036307
# 6 exposure outcome Z4DqzZ      uxBr3b     NA         rs11066132 -4.6064340
#   se        p
# 1 0.2245568 5.720257e-01
# 2 0.3865536 1.454978e-01
# 3 0.3774788 7.568699e-04
# 4 0.2983861 3.846048e-02
# 5 0.3686452 5.806908e-01
# 6 0.2461585 3.858432e-78

# %%
res_loo <- mr_leaveoneout(harmonized_data)
head(res_loo)
# Out:
#   exposure outcome id.exposure id.outcome samplesize SNP        b
# 1 exposure outcome Z4DqzZ      uxBr3b     NA         rs10198356 0.07628561
# 2 exposure outcome Z4DqzZ      uxBr3b     NA         rs1020222  0.08690929
# 3 exposure outcome Z4DqzZ      uxBr3b     NA         rs10276442 0.06141861
# 4 exposure outcome Z4DqzZ      uxBr3b     NA         rs10938397 0.06597634
# 5 exposure outcome Z4DqzZ      uxBr3b     NA         rs11041978 0.07641959
# 6 exposure outcome Z4DqzZ      uxBr3b     NA         rs11066132 0.23697800
#   se         p
# 1 0.15521326 0.6230806460
# 2 0.15270853 0.5692755564
# 3 0.15157333 0.6853251990
# 4 0.15332105 0.6669665509
# 5 0.15323953 0.6179951909
# 6 0.07198258 0.0009942185

# %%
res <- mr(harmonized_data)
p1 <- mr_scatter_plot(res, harmonized_data)
p1[[1]]
# Out:
# Analysing 'Z4DqzZ' on 'uxBr3b'

# %%
res_single <- mr_singlesnp(harmonized_data)
p2 <- mr_forest_plot(res_single)
p2[[1]]
# Out:
# Warning message:
# “Removed 1 row containing missing values or values outside the scale range
# (`geom_errorbarh()`).”
# Warning message:
# “Removed 1 row containing missing values or values outside the scale range
# (`geom_point()`).”

# %%
res_loo <- mr_leaveoneout(harmonized_data)
p3 <- mr_leaveoneout_plot(res_loo)
p3[[1]]
# Out:
# Warning message:
# “Removed 1 row containing missing values or values outside the scale range
# (`geom_errorbarh()`).”
# Warning message:
# “Removed 1 row containing missing values or values outside the scale range
# (`geom_point()`).”

# %%
res_single <- mr_singlesnp(harmonized_data)
p4 <- mr_funnel_plot(res_single)
p4[[1]]

# %% [markdown]
# # t2d on CAD

# %%
harmonized_data <- harmonise_data(exposure_dat=c_t2d_exp,
                                  outcome_dat=cad_outcome_dat)
# Out:
# Harmonising exposure (1BoN59) and outcome (uxBr3b)
#
# Removing the following SNPs for being palindromic with intermediate allele frequencies:
# rs256904, rs3812821, rs4237150, rs58304657, rs7161785, rs9348441

# %%
res <- mr(harmonized_data)
head(res)
# Out:
# Analysing '1BoN59' on 'uxBr3b'
#   id.exposure id.outcome outcome exposure method                    nsnp
# 1 1BoN59      uxBr3b     outcome exposure MR Egger                  110
# 2 1BoN59      uxBr3b     outcome exposure Weighted median           110
# 3 1BoN59      uxBr3b     outcome exposure Inverse variance weighted 110
# 4 1BoN59      uxBr3b     outcome exposure Simple mode               110
# 5 1BoN59      uxBr3b     outcome exposure Weighted mode             110
#   b           se         pval
# 1 0.002050378 0.03658305 0.95540775
# 2 0.035397581 0.02237432 0.11363516
# 3 0.043774808 0.01771883 0.01349149
# 4 0.071938268 0.04943939 0.14852104
# 5 0.048634451 0.03053443 0.11410678

# %%
mr_heterogeneity(harmonized_data)
# Out:
#   id.exposure id.outcome outcome exposure method                    Q
# 1 1BoN59      uxBr3b     outcome exposure MR Egger                  218.7431
# 2 1BoN59      uxBr3b     outcome exposure Inverse variance weighted 222.1787
#   Q_df Q_pval
# 1 108  1.631686e-09
# 2 109  9.564464e-10

# %%
mr_pleiotropy_test(harmonized_data)
# Out:
#   id.exposure id.outcome outcome exposure egger_intercept se         pval
# 1 1BoN59      uxBr3b     outcome exposure 0.004412424     0.00338794 0.1955531

# %%
res_single <- mr_singlesnp(harmonized_data)
head(res_single)
# Out:
#   exposure outcome id.exposure id.outcome samplesize SNP        b
# 1 exposure outcome 1BoN59      uxBr3b     NA         rs10258962 0.37573996
# 2 exposure outcome 1BoN59      uxBr3b     NA         rs10305435 0.03829371
# 3 exposure outcome 1BoN59      uxBr3b     NA         rs10418558 0.42425928
# 4 exposure outcome 1BoN59      uxBr3b     NA         rs10832835 0.05835717
# 5 exposure outcome 1BoN59      uxBr3b     NA         rs10882138 0.03802529
# 6 exposure outcome 1BoN59      uxBr3b     NA         rs10962    0.12822939
#   se        p
# 1 0.1435623 0.008863844
# 2 0.1690503 0.820794936
# 3 0.2034279 0.037019309
# 4 0.1796510 0.745304949
# 5 0.1617221 0.814109909
# 6 0.1369138 0.348979752

# %%
res_loo <- mr_leaveoneout(harmonized_data)
head(res_loo)
# Out:
#   exposure outcome id.exposure id.outcome samplesize SNP        b
# 1 exposure outcome 1BoN59      uxBr3b     NA         rs10258962 0.04127525
# 2 exposure outcome 1BoN59      uxBr3b     NA         rs10305435 0.04380451
# 3 exposure outcome 1BoN59      uxBr3b     NA         rs10418558 0.04235337
# 4 exposure outcome 1BoN59      uxBr3b     NA         rs10832835 0.04370488
# 5 exposure outcome 1BoN59      uxBr3b     NA         rs10882138 0.04380887
# 6 exposure outcome 1BoN59      uxBr3b     NA         rs10962    0.04307512
#   se         p
# 1 0.01764961 0.01935656
# 2 0.01784879 0.01411984
# 3 0.01769240 0.01667153
# 4 0.01784303 0.01430910
# 5 0.01785327 0.01413441
# 6 0.01785882 0.01586613

# %%
options(repr.plot.width=15, repr.plot.height=10)

# %%
res <- mr(harmonized_data)
p1 <- mr_scatter_plot(res, harmonized_data)
p1[[1]]
# Out:
# Analysing '1BoN59' on 'uxBr3b'

# %%
res_single <- mr_singlesnp(harmonized_data)
p2 <- mr_forest_plot(res_single)
p2[[1]]
# Out:
# Warning message:
# “Removed 1 row containing missing values or values outside the scale range
# (`geom_errorbarh()`).”
# Warning message:
# “Removed 1 row containing missing values or values outside the scale range
# (`geom_point()`).”

# %%
res_loo <- mr_leaveoneout(harmonized_data)
p3 <- mr_leaveoneout_plot(res_loo)
p3[[1]]
# Out:
# Warning message:
# “Removed 1 row containing missing values or values outside the scale range
# (`geom_errorbarh()`).”
# Warning message:
# “Removed 1 row containing missing values or values outside the scale range
# (`geom_point()`).”

# %%
res_single <- mr_singlesnp(harmonized_data)
p4 <- mr_funnel_plot(res_single)
p4[[1]]

# %% [markdown]
# # Multivariante MR

# %%
harmonised_data <- mv_harmonise_data(exposures_dat, cad_outcome_dat)
# Out:
# Harmonising fMpojc_T2D (fMpojc) and outcome (uxBr3b)

# %%
res <- mv_multiple(harmonised_data, plots = TRUE)

# %%
res
# Out:
# $result
#   id.exposure   exposure id.outcome outcome nsnp          b       se      pval
# 1      f1j5gq f1j5gq_BMI     uxBr3b outcome    3  0.4342437 2.011096 0.8290470
# 2      fMpojc fMpojc_T2D     uxBr3b outcome    1 -0.1001243 1.334473 0.9401915
#
# $plots
# $plots[[1]]
#
# $plots[[2]]

# %%
mr_heterogeneity(harmonised_data)
# Out:
# Error in mv_heterogeneity(harmonised_data): could not find function "mv_heterogeneity"
# Traceback:

# %% [markdown]
# ________________________________________
# _______________________________________
